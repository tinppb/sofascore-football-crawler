# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'D:\NAM 3\Ki II\Đồ án II\code crawl sofascore\du_lieu_da_xu_ly.csv',encoding='utf-8')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=df, x='price', bins=5)
plt.title("Phân bố giá điện thoại")
# Out:
# Text(0.5, 1.0, 'Phân bố giá điện thoại')

# %%
sns.countplot(data=df, x='operating_system')
plt.title("Số lượng sản phẩm theo hệ điều hành")
plt.xticks(rotation=45)
plt.show()
